# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,math.pi,1024)

# %%
np.sum(sinx)
# Out:
# 635.982628472229

# %%
np.sum(sinx[:11])
# Out:
# 0.1729448777477921

# %%
sinx = np.sin(x)

plt.plot(x,sinx)


total = np.sum(sinx)

listout = []
for idx, item in enumerate(sinx):
    listout.append(np.sum(sinx[:idx])/total)
    
listout = np.asarray(listout) 
LUT_sig = listout
plt.plot(x,listout)



def _depr_sigmoid(x,beta = 3):
    listout = []
    
    for idx, item in enumerate(x):
        listout.append( 1 / ( 1 + (item / (1 / item)) ** -beta  ) )
    return np.asarray(listout)
    #return 1 / (1 + math. exp(-x))
    
    
def sigmoid(x, k=0.4):
    listout = []
    for idx, item in enumerate(x-(math.pi/2)):
        listout.append( (1 / (1 + np.exp(-item / k)) ) )
    # sigmoid function
    # use k to adjust the slope
    return np.asarray(listout)

def norm(x):
    # normalise x to range [-1,1]
    nom = (x - x.min()) * 2.0
    denom = x.max() - x.min()
    return  nom/denom - 1.0

plt.plot(x,sigmoid(x))
plt.plot([0,math.pi],[0.5,0.5],"k--",alpha = 0.5, zorder = -1)



#plt.xticks(ticks=[0,math.pi/4,math.pi/2,3*(math.pi/4),math.pi],labels=["0","0.25","0.5","0.75","1"])
plt.show()

# %%
import os, sys
import scipy.interpolate as interp
sys.path.append(r"C:\Users\Timothe\NasgoyaveOC\Professionnel\TheseUNIC\Scripts\Python\Librairies_Tim")
from LibUtils import signal
help(signal.Interp1D)
# Out:
# Help on function Interp1D in module LibUtils.signal:
#
# Interp1D(signal, resample_rate=2, method='quadratic')
#     Expects a 1D np array as signal

# %%
funct = interp.interp1d(lutprim,xprim)
nex_X = np.linspace(0,1024,int(1024/2))
new_VAL = funct( nex_X )

# %%
xprime = np.linspace(0,1,100)
fig = plt.figure(figsize=(20,10))
xprim = x / math.pi * 9400  +100
lutprim = LUT_sig*1024



plt.plot(lutprim,  xprim )

plt.plot(nex_X,  new_VAL )
plt.show()
print(new_VAL.astype(int).tolist())
print(len(new_VAL.astype(int).tolist()))
# Out:
# [109, 369, 479, 563, 634, 697, 754, 806, 855, 901, 944, 985, 1025, 1063, 1099, 1134, 1169, 1202, 1234, 1265, 1296, 1326, 1355, 1383, 1411, 1439, 1466, 1492, 1518, 1544, 1569, 1593, 1618, 1642, 1665, 1689, 1712, 1734, 1757, 1779, 1801, 1823, 1844, 1865, 1886, 1907, 1928, 1948, 1968, 1988, 2008, 2028, 2047, 2066, 2085, 2104, 2123, 2142, 2160, 2179, 2197, 2215, 2233, 2251, 2269, 2286, 2304, 2321, 2339, 2356, 2373, 2390, 2407, 2424, 2440, 2457, 2473, 2490, 2506, 2522, 2538, 2555, 2571, 2586, 2602, 2618, 2634, 2649, 2665, 2680, 2696, 2711, 2726, 2742, 2757, 2772, 2787, 2802, 2817, 2832, 2846, 2861, 2876, 2890, 2905, 2919, 2934, 2948, 2963, 2977, 2991, 3006, 3020, 3034, 3048, 3062, 3076, 3090, 3104, 3118, 3132, 3145, 3159, 3173, 3186, 3200, 3214, 3227, 3241, 3254, 3268, 3281, 3295, 3308, 3321, 3335, 3348, 3361, 3374, 3387, 3401, 3414, 3427, 3440, 3453, 3466, 3479, 3492, 3505, 3518, 3530, 3543, 3556, 3569, 3582, 3594, 3607, 3620, 3633, 3645, 3658, 3670, 3683, 3696, 3708, 3721, 3733, 3746, 3
# ...

# %%
fig = plt.figure(figsize=(10,20))
xprimeprime = np.linspace(0,math.pi,10)
plt.plot(xprimeprime,xprimeprime,'o',markersize = 3)
